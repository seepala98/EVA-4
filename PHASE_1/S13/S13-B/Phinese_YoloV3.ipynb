# %% [markdown]
# <a href="https://colab.research.google.com/github/seepala98/EVA-4/blob/master/PHASE_1/S13/S13-B/Phinese_YoloV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd ..
# %ls
# Out:
# sample_data/

# %%
# !rm -rf YOLO-V3
# !git clone https://github.com/seepala98/YOLO-V3.git
# Out:
# Cloning into 'YOLO-V3'...
# remote: Enumerating objects: 963, done.
# remote: Counting objects: 100% (963/963), done.
# remote: Compressing objects: 100% (931/931), done.
# remote: Total 963 (delta 98), reused 838 (delta 5), pack-reused 0
# Receiving objects: 100% (963/963), 17.75 MiB | 16.78 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cp "/content/gdrive/My Drive/yolov3-spp-ultralytics.pt" /content/YOLO-V3/weights/

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
cd YOLO-V3/
# Out:
# /content/YOLO-V3

# %%
# !ls
# Out:
#  annotation_tool   __pycache__	  test_batch0.png   'ubdivisions=1'
#  cfg		   README.md	  test.py	     utils
#  data		   results.json   ting		     vim.exe.stackdump
#  detect.py	   results.png	  train_batch0.png   weights
#  models.py	   results.txt	  train.py

# %%
# !python train.py --data data/customdata/custom.data --batch 3 --cache --epochs 3 --nosave --cfg cfg/yolov3-custom.cfg --single-cls
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=True, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-25 14:39:27.559138: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (394 found, 0 missing, 1 empty, 0 duplicate, for 395 images): 100% 395/395 [00:00<00:00, 9065.47it/s]
# Caching images (0.2GB): 100% 395/395 [00:01<00:00, 363.53it/s]
# Reading image shapes: 100% 395/395 [00:00<00:00, 2026.04it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave --single-cls
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=True, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-25 14:43:14.066238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (394 found, 0 missing, 1 empty, 0 duplicate, for 395 images): 100% 395/395 [00:00<00:00, 10827.02it/s]
# Caching images (0.2GB): 100% 395/395 [00:01<00:00, 378.92it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_v3/output"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_v3/output', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/396 data/customdata/images/imag1.jpg: 320x512 1 phineses, Done. (0.034s)
# image 2/396 data/customdata/images/imag10.jpg: 320x512 1 phineses, Done. (0.033s)
# image 3/396 data/customdata/images/imag100.jpg: 448x512 1 phineses, Done. (0.035s)
# image 4/396 data/customdata/images/imag101.jpg: 384x512 1 phineses, Done. (0.029s)
# image 5/396 data/customdata/images/imag102.jpg: 512x512 1 phineses, Done. (0.034s)
# ...

# %%
Image(filename='/content/gdrive/My Drive/yolo_v3/output/imag1.jpg', width=600)

# %%
Image(filename='/content/gdrive/My Drive/yolo_v3/output/imag250.jpg', width=600)

# %%
Image(filename='/content/gdrive/My Drive/yolo_v3/output/imag320.jpg', width=600)

# %%
# !python detect.py --conf-thres 0.3 --output "/content/gdrive/My Drive/yolo_v3/output_vid4" --source "/content/gdrive/My Drive/Phineas And Ferb Theme Song in Telugu HD 1080p.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_v3/output_vid4', save_txt=False, source='/content/gdrive/My Drive/Phineas And Ferb Theme Song in Telugu HD 1080p.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/1677) /content/gdrive/My Drive/Phineas And Ferb Theme Song in Telugu HD 1080p.mp4: 320x512 Done. (0.034s)
# video 1/1 (2/1677) /content/gdrive/My Drive/Phineas And Ferb Theme Song in Telugu HD 1080p.mp4: 320x512 Done. (0.033s)
# video 1/1 (3/1677) /content/gdrive/My Drive/Phineas And Ferb Theme Song in Telugu HD 1080p.mp4: 320x512 Done. (0.028s)
# ...

# %%
# !python detect.py --conf-thres 0.3 --output "/content/gdrive/My Drive/yolo_v3/output_vid5" --source "/content/gdrive/My Drive/chone_phinese.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_v3/output_vid5', save_txt=False, source='/content/gdrive/My Drive/chone_phinese.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.035s)
# video 1/1 (2/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.032s)
# video 1/1 (3/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.026s)
# video 1/1 (4/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.026s)
# video 1/1 (5/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.026s)
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_v3/output_vid6" --source "/content/gdrive/My Drive/chone_phinese.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_v3/output_vid6', save_txt=False, source='/content/gdrive/My Drive/chone_phinese.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.035s)
# video 1/1 (2/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.033s)
# video 1/1 (3/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.033s)
# video 1/1 (4/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.033s)
# video 1/1 (5/2754) /content/gdrive/My Drive/chone_phinese.mp4: 320x512 Done. (0.028s)
# ...
